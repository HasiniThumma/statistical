# %%
import pandas as pd


data = [
    {"Name": "Hasini", "CGPA": 8.64},
    {"Name": "Sahithya", "CGPA": 9.09},
    {"Name": "Shruthi", "CGPA": 9.24},
    {"Name": "Deepthi", "CGPA": 9.45},
    {"Name": "Ronith", "CGPA": 6.3},
    {"Name": "Harshini", "CGPA": 8.5},
    {"Name": "Architha", "CGPA": 7.32},
    {"Name": "Varshitha", "CGPA": 9.4},
    {"Name": "Varshith", "CGPA": 9.0},
    {"Name": "Vishal", "CGPA": 8.5},
    {"Name": "Sri Kumar", "CGPA": 7.5},
    {"Name": "Preethi", "CGPA": 8.5},
    {"Name": "Akshaya", "CGPA": 9.0},
    {"Name": "Madhavi", "CGPA": 8.0},
    {"Name": "Srinidhi", "CGPA": 8.0},
    {"Name": "Abhilash", "CGPA": 9.3},
    {"Name": "Hariharan", "CGPA": 7.4},
    {"Name": "Bal Reddy", "CGPA": 7.3},
    {"Name": "Rahul", "CGPA": 8.0},
    {"Name": "Ananya", "CGPA": 7.31}
]

df = pd.DataFrame(data)


print(df)
# Out:
#          Name  CGPA
# 0      Hasini  8.64
# 1    Sahithya  9.09
# 2     Shruthi  9.24
# 3     Deepthi  9.45
# 4      Ronith  6.30
# 5    Harshini  8.50
# 6    Architha  7.32
# 7   Varshitha  9.40
# 8    Varshith  9.00
# 9      Vishal  8.50
# 10  Sri Kumar  7.50
# 11    Preethi  8.50
# 12    Akshaya  9.00
# 13    Madhavi  8.00
# 14   Srinidhi  8.00
# 15   Abhilash  9.30
# 16  Hariharan  7.40
# 17  Bal Reddy  7.30
# 18      Rahul  8.00
# 19     Ananya  7.31

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Step 1: Create the data
data = [
    {"Name": "Hasini", "CGPA": 8.64},
    {"Name": "Sahithya", "CGPA": 9.09},
    {"Name": "Shruthi", "CGPA": 9.24},
    {"Name": "Deepthi", "CGPA": 9.45},
    {"Name": "Ronith", "CGPA": 6.3},
    {"Name": "Harshini", "CGPA": 8.5},
    {"Name": "Architha", "CGPA": 7.32},
    {"Name": "Varshitha", "CGPA": 9.4},
    {"Name": "Varshith", "CGPA": 9.0},
    {"Name": "Vishal", "CGPA": 8.5},
    {"Name": "Sri Kumar", "CGPA": 7.5},
    {"Name": "Preethi", "CGPA": 8.5},
    {"Name": "Akshaya", "CGPA": 9.0},
    {"Name": "Madhavi", "CGPA": 8.0},
    {"Name": "Srinidhi", "CGPA": 8.0},
    {"Name": "Abhilash", "CGPA": 9.3},
    {"Name": "Hariharan", "CGPA": 7.4},
    {"Name": "Bal Reddy", "CGPA": 7.3},
    {"Name": "Rahul", "CGPA": 8.0},
    {"Name": "Ananya", "CGPA": 7.31}
]

# Step 2: Convert the data into a Pandas DataFrame
df = pd.DataFrame(data)

# Step 3: Generate the histogram with different colors
plt.figure(figsize=(14, 8))

# Generate colors
colors = plt.cm.viridis(np.linspace(0, 1, len(df)))

# Plot histogram
n, bins, patches = plt.hist(df['CGPA'], bins=6, edgecolor='black', alpha=0.7)

# Assign colors to each bar
for color, patch in zip(colors, patches):
    patch.set_facecolor(color)

plt.title('Distribution of CGPAs')
plt.xlabel('CGPA')
plt.ylabel('Frequency')
plt.grid(False)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Step 1: Create the data
data = [
    {"Name": "Hasini", "CGPA": 8.64},
    {"Name": "Sahithya", "CGPA": 9.09},
    {"Name": "Shruthi", "CGPA": 9.24},
    {"Name": "Deepthi", "CGPA": 9.45},
    {"Name": "Ronith", "CGPA": 6.3},
    {"Name": "Harshini", "CGPA": 8.5},
    {"Name": "Architha", "CGPA": 7.32},
    {"Name": "Varshitha", "CGPA": 9.4},
    {"Name": "Varshith", "CGPA": 9.0},
    {"Name": "Vishal", "CGPA": 8.5},
    {"Name": "Sri Kumar", "CGPA": 7.5},
    {"Name": "Preethi", "CGPA": 8.5},
    {"Name": "Akshaya", "CGPA": 9.0},
    {"Name": "Madhavi", "CGPA": 8.0},
    {"Name": "Srinidhi", "CGPA": 8.0},
    {"Name": "Abhilash", "CGPA": 9.3},
    {"Name": "Hariharan", "CGPA": 7.4},
    {"Name": "Bal Reddy", "CGPA": 7.3},
    {"Name": "Rahul", "CGPA": 8.0},
    {"Name": "Ananya", "CGPA": 7.31}
]

# Step 2: Convert the data into a Pandas DataFrame
df = pd.DataFrame(data)

# Step 3: Generate the bar plot with different colors
plt.figure(figsize=(14, 8))

# Generate colors using a colormap
colors = plt.cm.viridis(np.linspace(0, 1, len(df)))

bars = plt.bar(df['Name'], df['CGPA'], color=colors, edgecolor='black')
plt.title('CGPA of BTECH 1st Year Students')
plt.xlabel('Name')
plt.ylabel('CGPA')
plt.xticks(rotation=90)  # Rotate the x-axis labels for better readability
plt.grid(False)
plt.show()

# %%
import pandas as pd
import numpy as np
from scipy.stats import skew, kurtosis, mode

# Create the DataFrame
data = [
    {"Name": "Hasini", "CGPA": 8.64},
    {"Name": "Sahithya", "CGPA": 9.09},
    {"Name": "Shruthi", "CGPA": 9.24},
    {"Name": "Deepthi", "CGPA": 9.45},
    {"Name": "Ronith", "CGPA": 6.3},
    {"Name": "Harshini", "CGPA": 8.5},
    {"Name": "Architha", "CGPA": 7.32},
    {"Name": "Varshitha", "CGPA": 9.4},
    {"Name": "Varshith", "CGPA": 9.0},
    {"Name": "Vishal", "CGPA": 8.5},
    {"Name": "Sri Kumar", "CGPA": 7.5},
    {"Name": "Preethi", "CGPA": 8.5},
    {"Name": "Akshaya", "CGPA": 9.0},
    {"Name": "Madhavi", "CGPA": 8.0},
    {"Name": "Srinidhi", "CGPA": 8.0},
    {"Name": "Abhilash", "CGPA": 9.3},
    {"Name": "Hariharan", "CGPA": 7.4},
    {"Name": "Bal Reddy", "CGPA": 7.3},
    {"Name": "Rahul", "CGPA": 8.0},
    {"Name": "Ananya", "CGPA": 7.31}
]

df = pd.DataFrame(data)

# Calculate required statistics
mean_cgpa = df['CGPA'].mean()
median_cgpa = df['CGPA'].median()

# Correct way to calculate mode
mode_result = mode(df['CGPA'], keepdims=True)
mode_cgpa = mode_result.mode[0] if mode_result.count[0] > 1 else df['CGPA'].mode()[0]

variance_cgpa = df['CGPA'].var()
std_dev_cgpa = df['CGPA'].std()
range_cgpa = df['CGPA'].max() - df['CGPA'].min()
q1 = df['CGPA'].quantile(0.25)
q3 = df['CGPA'].quantile(0.75)
iqr_cgpa = q3 - q1
skewness_cgpa = skew(df['CGPA'])
kurtosis_cgpa = kurtosis(df['CGPA'])

# Print the results
print(f"Mean CGPA: {mean_cgpa}")
print(f"Median CGPA: {median_cgpa}")
print(f"Mode CGPA: {mode_cgpa}")
print(f"Variance CGPA: {variance_cgpa}")
print(f"Standard Deviation CGPA: {std_dev_cgpa}")
print(f"Range CGPA: {range_cgpa}")
print(f"Interquartile Range (IQR) CGPA: {iqr_cgpa}")
print(f"Skewness CGPA: {skewness_cgpa}")
print(f"Kurtosis CGPA: {kurtosis_cgpa}")
# Out:
# Mean CGPA: 8.287500000000001
# Median CGPA: 8.5
# Mode CGPA: 8.0
# Variance CGPA: 0.7849039473684212
# Standard Deviation CGPA: 0.8859480500392904
# Range CGPA: 3.1499999999999995
# Interquartile Range (IQR) CGPA: 1.5475000000000012
# Skewness CGPA: -0.44646024682364355
# Kurtosis CGPA: -0.7020763247181345
